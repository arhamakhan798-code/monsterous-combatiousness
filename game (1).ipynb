# %%
import random

def handle_move(Move, Mh, Uh):
    if Move == "A":
        Mh = Mh - random.randint(1, 40)
    elif Move == "B":
        Mh = Mh - random.randint(20, 30)
    else:
        Uh = Uh + random.randint(20, 30)

    # Return the updated health values back to your main game
    return Mh, Uh

def move():
  Move=input("Enter your move trash piece: ").upper()
  while Move not in [ "A", "B", "C" ]:
      Move=input("You piece of trash, don't you know the rules I mentioned, pick move again").upper()
  return Move

print("Welcome back motherfucker!")
Name = input("Write your name dumbass: ")
while True:
    try:
        # Try to get the input, convert it to a float (to handle trailing dots like '12.'), then to an int
        Age = int(float(input("Drop your age bastard: ")))
        break  # If it works, break out of the loop!
    except ValueError:
        print("I will spank your ass red dickaddict slutty shit, put your ageee!")
print("A : First,")
print("B : Kick,")
print("C : Heal.")
print("Your Health: 100")
print("Monster Health: 100")
Uh = int(100)
Mh = int(100)

print("Monster : hahaha, this motherfucker piece of ant gonna fight me, hahaha I will smash this trash shitpiece with my pinky finger, hahahaha")

while Mh > 0 and Uh > 0:
  Move = move()
  # Example of calling your new function:
  Mh, Uh = handle_move(Move, Mh, Uh)
  if Uh >= 100:
    Uh = 100
  if Mh < 1:
    Mh = 0
    print("Monster: Motherfucker, you got a powerfull ass!")
    print(f"Congratulations {Name}")
    break
  else:
    print(f"Your health: {Uh}")
    print(f"Monsters health: {Mh}")

  print("Monster: hahaha somebody got moves hahaha, take this!")
  Uh = Uh - random.randint(20, 40)
  print(f"Your health: {Uh}")
  print(f"Monsters health: {Mh}")
  if Uh < 1:
    Uh = 0
    print(f"Your health: {Uh}")
    print(f"Monsters health: {Mh}")
    print("Monster: Useless nobody! Get your dirty loser ass out of my sight")
# Out:
# Welcome back motherfucker!
# Write your name dumbass: Arham
# Drop your age bastard: 19
# A : First,
# B : Kick,
# C : Heal.
# Your Health: 100
# Monster Health: 100
# Monster : hahaha, this motherfucker piece of ant gonna fight me, hahaha I will smash this trash shitpiece with my pinky finger, hahahaha
# Enter your move trash piece: P
# You piece of trash, don't you know the rules I mentioned, pick move againPpp
# You piece of trash, don't you know the rules I mentioned, pick move againA
# Your health: 100
# Monsters health: 78
# Monster: hahaha somebody got moves hahaha, take this!
# Enter your move trash piece: B
# Your health: 63
# Monsters health: 50
# Monster: hahaha somebody got moves hahaha, take this!
# Enter your move trash piece: H
# You piece of trash, don't you know the rules I mentioned, pick move againC
# Your health: 68
# Monsters health: 50
# Monster: hahaha somebody got moves hahaha, take this!
# Enter your move trash piece: A
# Your health: 42
# ...
